# %%
import pandas as pd

filename = "https://raw.githubusercontent.com/lvmeninnovations/datasets/main/crispdm/auto.csv"

headers = ["factor-riesgo","perdida-promedio-anual","fabricante","tipo-combustible","aspiracion", "num-puertas","estilo-carroceria",
         "traccion","ubicacion-motor","distancia-entre-ejes", "longitud","anchura","altura","peso-vacio","tipo-motor",
         "num-cilindros", "tamano-motor","sistema-combustible","calibre","carrera","relacion-compresion","caballos-fuerza",
         "pico-rpm","millas_por_galon_ciudad","millas_por_galon_carretera","precio"]

df = pd.read_csv(filename,names=headers)

# %%
df.head()
# Out:
#    factor-riesgo perdida-promedio-anual   fabricante tipo-combustible  \
# 0              3                      ?  alfa-romero              gas
# 1              3                      ?  alfa-romero              gas
# 2              1                      ?  alfa-romero              gas
# 3              2                    164         audi              gas
# 4              2                    164         audi              gas
#
#   aspiracion num-puertas estilo-carroceria traccion ubicacion-motor  \
# 0        std         two       convertible      rwd           front
# 1        std         two       convertible      rwd           front
# 2        std         two         hatchback      rwd           front
# 3        std        four             sedan      fwd           front
# 4        std        four             sedan      4wd           front
#
#    distancia-entre-ejes  ...  tamano-motor  sistema-combustible  calibre  \
# 0                  88.6  ...           130                 mpfi     3.47
# 1                  88.6  ...           130                 mpfi     3.47
# 2                  94.5  ...           152                 mpfi     2.68
# 3                  99.8  ...           109                 mpfi     3.19
# 4                  99.4  ...           136                 mpfi     3.19
#
#    carrera relacion-compresion caballos-fuerza  pico-rpm  \
# 0     2.68                 9.0             111      5000
# 1     2.68                 9.0             111      5000
# 2     3.47                 9.0             154      5000
# 3     3.40                10.0             102      5500
# 4     3.40                 8.0             115      5500
#
#   millas_por_galon_ciudad millas_por_galon_carretera precio
# 0                      21                         27  13495
# 1                      21                         27  16500
# 2                      19                         26  16500
# 3                      24                         30  13950
# 4                      18                         22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# Pasos para trabajar con datos perdidos.
#
#     Identificar valores perdidos
#     Lidiar con valores perdidos
#     Corregir formato de datos

# %%
import numpy as np

df.replace("?",np.nan,inplace=True)
df.head()
# Out:
#    factor-riesgo perdida-promedio-anual   fabricante tipo-combustible  \
# 0              3                    NaN  alfa-romero              gas
# 1              3                    NaN  alfa-romero              gas
# 2              1                    NaN  alfa-romero              gas
# 3              2                    164         audi              gas
# 4              2                    164         audi              gas
#
#   aspiracion num-puertas estilo-carroceria traccion ubicacion-motor  \
# 0        std         two       convertible      rwd           front
# 1        std         two       convertible      rwd           front
# 2        std         two         hatchback      rwd           front
# 3        std        four             sedan      fwd           front
# 4        std        four             sedan      4wd           front
#
#    distancia-entre-ejes  ...  tamano-motor  sistema-combustible  calibre  \
# 0                  88.6  ...           130                 mpfi     3.47
# 1                  88.6  ...           130                 mpfi     3.47
# 2                  94.5  ...           152                 mpfi     2.68
# 3                  99.8  ...           109                 mpfi     3.19
# 4                  99.4  ...           136                 mpfi     3.19
#
#    carrera relacion-compresion caballos-fuerza  pico-rpm  \
# 0     2.68                 9.0             111      5000
# 1     2.68                 9.0             111      5000
# 2     3.47                 9.0             154      5000
# 3     3.40                10.0             102      5500
# 4     3.40                 8.0             115      5500
#
#   millas_por_galon_ciudad millas_por_galon_carretera precio
# 0                      21                         27  13495
# 1                      21                         27  16500
# 2                      19                         26  16500
# 3                      24                         30  13950
# 4                      18                         22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# Una vez convertidos los datos perdidos a los valores predeterminados de Python, pasamos a utilizar funciones integradas de Python que nos permiten identificar estos datos. Hay tres métodos para detectar valores perdidos: .isnull(), .notnull() y .isna().

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    factor-riesgo  perdida-promedio-anual  fabricante  tipo-combustible  \
# 0          False                    True       False             False
# 1          False                    True       False             False
# 2          False                    True       False             False
# 3          False                   False       False             False
# 4          False                   False       False             False
#
#    aspiracion  num-puertas  estilo-carroceria  traccion  ubicacion-motor  \
# 0       False        False              False     False            False
# 1       False        False              False     False            False
# 2       False        False              False     False            False
# 3       False        False              False     False            False
# 4       False        False              False     False            False
#
#    distancia-entre-ejes  ...  tamano-motor  sistema-combustible  calibre  \
# 0                 False  ...         False                False    False
# 1                 False  ...         False                False    False
# 2                 False  ...         False                False    False
# 3                 False  ...         False                False    False
# 4                 False  ...         False                False    False
#
#    carrera  relacion-compresion  caballos-fuerza  pico-rpm  \
# 0    False                False            False     False
# 1    False                False            False     False
# 2    False                False            False     False
# 3    False                False            False     False
# 4    False                False            False     False
#
#    millas_por_galon_ciudad  millas_por_galon_carretera  precio
# 0                    False                       False   False
# 1                    False                       False   False
# 2                    False                       False   False
# 3                    False                       False   False
# 4                    False                       False   False
#
# [5 rows x 26 columns]

# %% [markdown]
# Utilizando un bucle for podemos calcular el número de valores perdidos de cada columna.

# %%
for column in missing_data.columns.values.tolist():
  print(column)
  print(missing_data[column].value_counts())
  print("-------------------------")
# Out:
# factor-riesgo
# factor-riesgo
# False    205
# Name: count, dtype: int64
# -------------------------
# perdida-promedio-anual
# perdida-promedio-anual
# False    164
# True      41
# Name: count, dtype: int64
# -------------------------
# fabricante
# fabricante
# False    205
# Name: count, dtype: int64
# -------------------------
# tipo-combustible
# tipo-combustible
# False    205
# Name: count, dtype: int64
# -------------------------
# aspiracion
# aspiracion
# False    205
# Name: count, dtype: int64
# -------------------------
# num-puertas
# num-puertas
# False    203
# True       2
# Name: count, dtype: int64
# -------------------------
# estilo-carroceria
# estilo-carroceria
# False    205
# Name: count, dtype: int64
# -------------------------
# traccion
# traccion
# False    205
# Name: count, dtype: int64
# -------------------------
# ubicacion-motor
# ubicacion-motor
# False    205
# Name: count, dtype: int64
# -------------------------
# distancia-entre-ejes
# distancia-entre-ejes
# False    205
# Name: count, dtype: int64
# -------------------------
# longitud
# longitud
# False    205
# Name: count, dtype: int64
# -------------------------
# anchura
# anchura
# False    205
# Name: count, dtype: int64
# -------------------------
# altura
# altura
# False    205
# Name: count, dtype: int64
# -------------------------
# peso-vacio
# peso-vacio
# False    205
# Name: count, dtype: int64
# -------------------------
# tipo-motor
# tipo-motor
# False    205
# Name: count, dtype: int64
# -------------------------
# num-cilindros
# num-cilindros
# False    205
# Name: count, dtype: int64
# -------------------------
# tamano-motor
# tamano-motor
# False    205
# Name: count, dtype: int64
# -------------------------
# sistema-combustible
# sistema-combustible
# False    205
# Name: count, dtype: int64
# -------------------------
# calibre
# calibre
# False    201
# True       4
# Name: count, dtype: int64
# -------------------------
# carrera
# carrera
# False    201
# True       4
# Name: count, dtype: int64
# -------------------------
# relacion-compresion
# relacion-compresion
# False    205
# Name: count, dtype: int64
# -------------------------
# caballos-fuerza
# caballos-fuerza
# False    203
# True       2
# Name: count, dtype: int64
# -------------------------
# pico-rpm
# pico-rpm
# False    203
# True       2
# Name: count, dtype: int64
# -------------------------
# millas_por_galon_ciudad
# millas_por_galon_ciudad
# False    205
# Name: count, dtype: int64
# -------------------------
# millas_por_galon_carretera
# millas_por_galon_carretera
# False    205
# Name: count, dtype: int64
# -------------------------
# precio
# precio
# False    201
# True       4
# Name: count, dtype: int64
# -------------------------

# %% [markdown]
# EJERCICIO 1:

# %%
result_df = pd.DataFrame({
    "isna": df.isna().sum(),
    "isnull": df.isnull().sum(),
    "notnull": df.notnull().sum()
})
result_df
# Out:
#                             isna  isnull  notnull
# factor-riesgo                  0       0      205
# perdida-promedio-anual        41      41      164
# fabricante                     0       0      205
# tipo-combustible               0       0      205
# aspiracion                     0       0      205
# num-puertas                    2       2      203
# estilo-carroceria              0       0      205
# traccion                       0       0      205
# ubicacion-motor                0       0      205
# distancia-entre-ejes           0       0      205
# longitud                       0       0      205
# anchura                        0       0      205
# altura                         0       0      205
# peso-vacio                     0       0      205
# tipo-motor                     0       0      205
# num-cilindros                  0       0      205
# tamano-motor                   0       0      205
# sistema-combustible            0       0      205
# calibre                        4       4      201
# carrera                        4       4      201
# relacion-compresion            0       0      205
# caballos-fuerza                2       2      203
# pico-rpm                       2       2      203
# millas_por_galon_ciudad        0       0      205
# millas_por_galon_carretera     0       0      205
# precio                         4       4      201

# %% [markdown]
# Cuando tenemos un dataset con valores perdidos, podemos tomar las siguientes decisiones:
#
#     Eliminar datos
#
#     Eliminar toda la fila
#
#     Eliminar toda la columna
#
#     Reemplazar datos
#
#     Reemplazar por la media (o promedio)
#
#     Reemplazar por la frecuencia
#
#     Reemplazar en función de otras funciones

# %%
# Reemplazando por la media:

avg_perdida_promedio_anual = df["perdida-promedio-anual"].astype("float").mean()
avg_carrera = df["carrera"].astype("float").mean()
avg_calibre = df["calibre"].astype("float").mean()

df["perdida-promedio-anual"].replace(np.nan, avg_perdida_promedio_anual, inplace=True)
df["carrera"].replace(np.nan, avg_carrera, inplace=True)
df["calibre"].replace(np.nan, avg_calibre, inplace=True)

df.head()
# Out:
#    factor-riesgo perdida-promedio-anual   fabricante tipo-combustible  \
# 0              3                  122.0  alfa-romero              gas
# 1              3                  122.0  alfa-romero              gas
# 2              1                  122.0  alfa-romero              gas
# 3              2                    164         audi              gas
# 4              2                    164         audi              gas
#
#   aspiracion num-puertas estilo-carroceria traccion ubicacion-motor  \
# 0        std         two       convertible      rwd           front
# 1        std         two       convertible      rwd           front
# 2        std         two         hatchback      rwd           front
# 3        std        four             sedan      fwd           front
# 4        std        four             sedan      4wd           front
#
#    distancia-entre-ejes  ...  tamano-motor  sistema-combustible  calibre  \
# 0                  88.6  ...           130                 mpfi     3.47
# 1                  88.6  ...           130                 mpfi     3.47
# 2                  94.5  ...           152                 mpfi     2.68
# 3                  99.8  ...           109                 mpfi     3.19
# 4                  99.4  ...           136                 mpfi     3.19
#
#    carrera relacion-compresion caballos-fuerza  pico-rpm  \
# 0     2.68                 9.0             111      5000
# 1     2.68                 9.0             111      5000
# 2     3.47                 9.0             154      5000
# 3     3.40                10.0             102      5500
# 4     3.40                 8.0             115      5500
#
#   millas_por_galon_ciudad millas_por_galon_carretera precio
# 0                      21                         27  13495
# 1                      21                         27  16500
# 2                      19                         26  16500
# 3                      24                         30  13950
# 4                      18                         22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# EJERCICIO 2:

# %%
avg_caballos_fuerza = df["caballos-fuerza"].astype("float").mean()
df["caballos-fuerza"].fillna(avg_caballos_fuerza,inplace=True)

print(f"Promedio de caballos de fuerza: ${avg_caballos_fuerza:.2f}")
df["caballos-fuerza"]
# Out:
# Promedio de caballos de fuerza: $104.26
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: caballos-fuerza, Length: 205, dtype: object

# %%
# Reemplazar por la frecuencia
df["num-puertas"].value_counts()
# Out:
# num-puertas
# four    114
# two      89
# Name: count, dtype: int64

# %%
df["num-puertas"].replace(np.nan, "four", inplace=True)

# %%
# Eliminar toda la fila
df.dropna(subset=["precio"],axis=0,inplace=True)
df.dropna(subset=["pico-rpm"],axis=0,inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
result_df = pd.DataFrame({
    "isna": df.isna().sum(),
    "isnull": df.isnull().sum(),
    "notnull": df.notnull().sum()
})
result_df
# Out:
#                             isna  isnull  notnull
# factor-riesgo                  0       0      199
# perdida-promedio-anual         0       0      199
# fabricante                     0       0      199
# tipo-combustible               0       0      199
# aspiracion                     0       0      199
# num-puertas                    0       0      199
# estilo-carroceria              0       0      199
# traccion                       0       0      199
# ubicacion-motor                0       0      199
# distancia-entre-ejes           0       0      199
# longitud                       0       0      199
# anchura                        0       0      199
# altura                         0       0      199
# peso-vacio                     0       0      199
# tipo-motor                     0       0      199
# num-cilindros                  0       0      199
# tamano-motor                   0       0      199
# sistema-combustible            0       0      199
# calibre                        0       0      199
# carrera                        0       0      199
# relacion-compresion            0       0      199
# caballos-fuerza                0       0      199
# pico-rpm                       0       0      199
# millas_por_galon_ciudad        0       0      199
# millas_por_galon_carretera     0       0      199
# precio                         0       0      199

# %%
# Corregir formato de datos
df[["calibre", "carrera"]] = df[["calibre", "carrera"]].astype("float")
df[["perdida-promedio-anual"]] = df[["perdida-promedio-anual"]].astype("int")
df[["precio"]] = df[["precio"]].astype("float")
df[["pico-rpm"]] = df[["pico-rpm"]].astype("float")

# %%
df.dtypes
# Out:
# factor-riesgo                   int64
# perdida-promedio-anual          int64
# fabricante                     object
# tipo-combustible               object
# aspiracion                     object
# num-puertas                    object
# estilo-carroceria              object
# traccion                       object
# ubicacion-motor                object
# distancia-entre-ejes          float64
# longitud                      float64
# anchura                       float64
# altura                        float64
# peso-vacio                      int64
# tipo-motor                     object
# num-cilindros                  object
# tamano-motor                    int64
# sistema-combustible            object
# calibre                       float64
# carrera                       float64
# relacion-compresion           float64
# caballos-fuerza                object
# pico-rpm                      float64
# millas_por_galon_ciudad         int64
# millas_por_galon_carretera      int64
# precio                        float64
# dtype: object

# %%
# Estandarizar datos
df['ciudad-L/100km'] = 235/df["millas_por_galon_ciudad"]

# %% [markdown]
# EJERCICIO 3:

# %%
# Transformando millas por galón a litros por 100 km
lp100km = 235/df["millas_por_galon_carretera"]

df["millas_por_galon_carretera"] = lp100km

df.rename(columns={ "millas_por_galon_carretera": "carretera-L/100km" },inplace=True)
df.columns
# Out:
# Index(['factor-riesgo', 'perdida-promedio-anual', 'fabricante',
#        'tipo-combustible', 'aspiracion', 'num-puertas', 'estilo-carroceria',
#        'traccion', 'ubicacion-motor', 'distancia-entre-ejes', 'longitud',
#        'anchura', 'altura', 'peso-vacio', 'tipo-motor', 'num-cilindros',
#        'tamano-motor', 'sistema-combustible', 'calibre', 'carrera',
#        'relacion-compresion', 'caballos-fuerza', 'pico-rpm',
#        'millas_por_galon_ciudad', 'carretera-L/100km', 'precio',
#        'ciudad-L/100km'],
#       dtype='object')

# %%
# Normalización de los datos
df["longitud"] = df["longitud"] / df["longitud"].max()
df["anchura"] = df["anchura"] / df["anchura"].max()

df[["longitud","anchura"]].head()
# Out:
#    longitud   anchura
# 0  0.811148  0.890278
# 1  0.811148  0.890278
# 2  0.822681  0.909722
# 3  0.848630  0.919444
# 4  0.848630  0.922222

# %% [markdown]
# EJERCICIO 4:

# %%
# Normalizando la columna altura
df["altura"] = df["altura"] / df["altura"].max()
df["altura"]
# Out:
# 0      0.816054
# 1      0.816054
# 2      0.876254
# 3      0.908027
# 4      0.908027
#          ...
# 194    0.928094
# 195    0.928094
# 196    0.928094
# 197    0.928094
# 198    0.928094
# Name: altura, Length: 199, dtype: float64

# %% [markdown]
# **Discretizar:** es el proceso de transformar variables numéricas continuas en discretas categóricas

# %%
# Discretizando caballos de fuerza

df["caballos-fuerza"]=df["caballos-fuerza"].astype("int", copy=True)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

plt.pyplot.hist(df["caballos-fuerza"])

plt.pyplot.xlabel("caballos-fuerza")
plt.pyplot.ylabel("conteo de automóviles")
plt.pyplot.title("caballos de fuerza vs #automóviles")
# Out:
# Text(0.5, 1.0, 'caballos de fuerza vs #automóviles')

# %%
bins = np.linspace(min(df["caballos-fuerza"]),max(df["caballos-fuerza"]),4)
group_names = ["low","Medium","High"]

# %%
# nota: la función cut ayuda a determinar a qué categoría pertenece cada valor de la columna
df["caballos-fuerza-discretos"] = pd.cut(df["caballos-fuerza"],bins,labels=group_names,include_lowest=True)
df[["caballos-fuerza","caballos-fuerza-discretos"]].head(10)
# Out:
#    caballos-fuerza caballos-fuerza-discretos
# 0              111                       low
# 1              111                       low
# 2              154                    Medium
# 3              102                       low
# 4              115                       low
# 5              110                       low
# 6              110                       low
# 7              110                       low
# 8              140                    Medium
# 9              101                       low

# %%
df["caballos-fuerza-discretos"].value_counts()
# Out:
# caballos-fuerza-discretos
# low       151
# Medium     43
# High        5
# Name: count, dtype: int64

# %%
pyplot.bar(group_names, df["caballos-fuerza-discretos"].value_counts())

plt.pyplot.xlabel("caballos-fuerza")
plt.pyplot.ylabel("conteo de automóviles")
plt.pyplot.title("caballos de fuerza (valores discretos) vs #automóviles")
# Out:
# Text(0.5, 1.0, 'caballos de fuerza (valores discretos) vs #automóviles')

# %%
a = (0,1,2)

plt.pyplot.hist(df["caballos-fuerza"],bins=3)

plt.pyplot.xlabel("caballos-fuerza")
plt.pyplot.ylabel("conteo de automóviles")
plt.pyplot.title("caballos-fuerza por rangos")
# Out:
# Text(0.5, 1.0, 'caballos-fuerza por rangos')

# %% [markdown]
# **Variable Indicadora:** es una variable numérica que se utiliza para etiquetar categorías. Los números en sí no representan una cantidad y por lo tanto no tienen un significado inherente.

# %%
# Obteniendo variables indicadoras para cada tipo de combustible:
dummy_variables = pd.get_dummies(df["tipo-combustible"]).astype(int)
dummy_variables.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %%
dummy_variables.rename(columns={ "gas": "tipo-combustible-gas", "diesel": "tipo-combustible-diesel" },inplace=True)
dummy_variables.head()
# Out:
#    tipo-combustible-diesel  tipo-combustible-gas
# 0                    False                  True
# 1                    False                  True
# 2                    False                  True
# 3                    False                  True
# 4                    False                  True

# %%
df = pd.concat([df,dummy_variables],axis=1)
df.drop("tipo-combustible",axis=1,inplace=True)
df.head()
# Out:
#    factor-riesgo  perdida-promedio-anual   fabricante aspiracion num-puertas  \
# 0              3                     122  alfa-romero        std         two
# 1              3                     122  alfa-romero        std         two
# 2              1                     122  alfa-romero        std         two
# 3              2                     164         audi        std        four
# 4              2                     164         audi        std        four
#
#   estilo-carroceria traccion ubicacion-motor  distancia-entre-ejes  longitud  \
# 0       convertible      rwd           front                  88.6  0.811148
# 1       convertible      rwd           front                  88.6  0.811148
# 2         hatchback      rwd           front                  94.5  0.822681
# 3             sedan      fwd           front                  99.8  0.848630
# 4             sedan      4wd           front                  99.4  0.848630
#
#    ...  relacion-compresion  caballos-fuerza  pico-rpm  \
# 0  ...                  9.0              111    5000.0
# 1  ...                  9.0              111    5000.0
# 2  ...                  9.0              154    5000.0
# 3  ...                 10.0              102    5500.0
# 4  ...                  8.0              115    5500.0
#
#   millas_por_galon_ciudad carretera-L/100km   precio ciudad-L/100km  \
# 0                      21          8.703704  13495.0      11.190476
# 1                      21          8.703704  16500.0      11.190476
# 2                      19          9.038462  16500.0      12.368421
# 3                      24          7.833333  13950.0       9.791667
# 4                      18         10.681818  17450.0      13.055556
#
#    caballos-fuerza-discretos  tipo-combustible-diesel  tipo-combustible-gas
# 0                        low                    False                  True
# 1                        low                    False                  True
# 2                     Medium                    False                  True
# 3                        low                    False                  True
# 4                        low                    False                  True
#
# [5 rows x 29 columns]

# %% [markdown]
# **EJERCICIO 5:**

# %%
df["aspiracion"]
# Out:
# 0        std
# 1        std
# 2        std
# 3        std
# 4        std
#        ...
# 194      std
# 195    turbo
# 196      std
# 197    turbo
# 198    turbo
# Name: aspiracion, Length: 199, dtype: object

# %%
aspiracion_dummies = pd.get_dummies(df["aspiracion"]).astype(int)
aspiracion_dummies.head()
# Out:
#     std  turbo
# 0  True  False
# 1  True  False
# 2  True  False
# 3  True  False
# 4  True  False

# %%
aspiracion_dummies.rename(columns={ "std": "aspiracion_std", "turbo": "aspiracion_turbo" }, inplace=True)

# %%
df = pd.concat([df,aspiracion_dummies],axis=1)

# %%
df.drop("aspiracion",axis=1,inplace=True)
df.head()
# Out:
#    factor-riesgo  perdida-promedio-anual   fabricante num-puertas  \
# 0              3                     122  alfa-romero         two
# 1              3                     122  alfa-romero         two
# 2              1                     122  alfa-romero         two
# 3              2                     164         audi        four
# 4              2                     164         audi        four
#
#   estilo-carroceria traccion ubicacion-motor  distancia-entre-ejes  longitud  \
# 0       convertible      rwd           front                  88.6  0.811148
# 1       convertible      rwd           front                  88.6  0.811148
# 2         hatchback      rwd           front                  94.5  0.822681
# 3             sedan      fwd           front                  99.8  0.848630
# 4             sedan      4wd           front                  99.4  0.848630
#
#     anchura  ...  pico-rpm  millas_por_galon_ciudad carretera-L/100km  \
# 0  0.890278  ...    5000.0                       21          8.703704
# 1  0.890278  ...    5000.0                       21          8.703704
# 2  0.909722  ...    5000.0                       19          9.038462
# 3  0.919444  ...    5500.0                       24          7.833333
# 4  0.922222  ...    5500.0                       18         10.681818
#
#     precio  ciudad-L/100km caballos-fuerza-discretos  tipo-combustible-diesel  \
# 0  13495.0       11.190476                       low                    False
# 1  16500.0       11.190476                       low                    False
# 2  16500.0       12.368421                    Medium                    False
# 3  13950.0        9.791667                       low                    False
# 4  17450.0       13.055556                       low                    False
#
#    tipo-combustible-gas  aspiracion_std  aspiracion_turbo
# 0                  True            True             False
# 1                  True            True             False
# 2                  True            True             False
# 3                  True            True             False
# 4                  True            True             False
#
# [5 rows x 30 columns]
